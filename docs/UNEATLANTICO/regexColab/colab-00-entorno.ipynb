# %% [markdown]
# # El entorno
#
# Las celdas grises contienen código. Se ejecutan una a una con ▶ o con `Ctrl+Enter`. El resultado aparece justo debajo.

# %%
print("hola")

# %%
nombre = "Ibuprofeno"
print(nombre)

# %%
texto = "Ghosting, mansplaining y scrollear son anglicismos de uso frecuente."
print(texto)
print(len(texto))

# %% [markdown]
# El mismo patrón que en regexr.com, sobre ese texto:

# %%
import re

resultado = re.findall(r"\b\w+ing\b", texto)
print(resultado)

# %% [markdown]
# En el siguiente notebook, el texto son 25 fragmentos.
